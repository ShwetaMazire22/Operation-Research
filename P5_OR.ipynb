# %% [markdown]
# # BigM Simplex Method using Python

# %%
from scipy.optimize import linprog
obj = [4, 1]

# %%
lhs_ineq = [[ -3, -4], # left side of first constraint
            [-1, -5]] # right side of first constraint

# %%
rhs_ineq = [-20, # left side of first constraint
            15] # right side of first constraint

# %%
bnd = [(0, float("inf")), # Bounds of x1
       (0, float("inf"))] # Bounds of x2

# %%
opt = linprog(c=obj, A_ub=lhs_ineq, b_ub=rhs_ineq,
              bounds=bnd, method="interior-point")

# %%
opt
# Out:
#      con: array([], dtype=float64)
#      fun: 5.000000000000993
#  message: 'Optimization terminated successfully.'
#      nit: 6
#    slack: array([-2.97362135e-12,  4.00000000e+01])
#   status: 0
#  success: True
#        x: array([5.34159454e-13, 5.00000000e+00])
